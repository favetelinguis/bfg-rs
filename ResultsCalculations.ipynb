# %%
import pandas as pd
import os
from pathlib import Path

# %%
home = str(Path.home())
filepaths = [f'{home}/bfg/demo/{f}' for f in os.listdir(home + '/bfg/demo') if f.endswith('.csv')]
df = pd.concat(map(pd.read_csv, filepaths))

# %% [markdown]
# Expectency and SQN

# %%
df
# Out:
#                   epic      reference  wanted_entry_level  \
# 0     IX.D.DAX.IFMM.IP      OVER_LONG             14401.7
# 1     IX.D.DAX.IFMM.IP      OVER_LONG             14401.7
# 2     IX.D.DAX.IFMM.IP      OVER_LONG             14401.7
# 3     IX.D.DAX.IFMM.IP      OVER_LONG             14401.7
# 0   IX.D.NASDAQ.IFE.IP      OVER_LONG             12671.9
# 1    IX.D.SPTRD.IFE.IP      OVER_LONG              4127.7
# 2    IX.D.SPTRD.IFE.IP  BETWEEN_SHORT              4127.3
# 3    IX.D.SPTRD.IFE.IP      OVER_LONG              4127.7
# 4    IX.D.SPTRD.IFE.IP      OVER_LONG              4127.7
# 5    IX.D.SPTRD.IFE.IP  BETWEEN_SHORT              4127.3
# 6    IX.D.SPTRD.IFE.IP      OVER_LONG              4127.7
# 7   IX.D.NASDAQ.IFE.IP    UNDER_SHORT             12639.1
# 8    IX.D.SPTRD.IFE.IP    UNDER_SHORT              4123.3
# 0     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 1     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 2     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 3     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 4     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 5     IX.D.DAX.IFMM.IP    UNDER_SHORT             14460.0
# 6     IX.D.DAX.IFMM.IP    UNDER_SHORT             14460.0
# 7     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 8     IX.D.DAX.IFMM.IP    UNDER_SHORT             14460.0
# 9     IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 10    IX.D.DAX.IFMM.IP    UNDER_SHORT             14460.0
# 11    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 12    IX.D.DAX.IFMM.IP    UNDER_SHORT             14460.0
# 13    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 14    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 15    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 16    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 17    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 18    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
# 19    IX.D.DAX.IFMM.IP    UNDER_SHORT             14460.0
# 20    IX.D.DAX.IFMM.IP   BETWEEN_LONG             14461.4
#
#                            entry_time  actual_entry_level  \
# 0   2022-06-02 07:05:23.209935326 UTC             14401.7
# 1   2022-06-02 07:06:53.261714282 UTC             14401.7
# 2   2022-06-02 07:09:04.646140018 UTC             14401.7
# 3   2022-06-02 07:11:27.787689466 UTC             14401.7
# 0   2022-06-03 13:36:12.548695615 UTC             12671.9
# 1   2022-06-03 13:36:59.342666860 UTC              4127.7
# 2   2022-06-03 13:37:43.104952041 UTC              4127.3
# 3   2022-06-03 14:11:24.775965935 UTC              4127.7
# 4   2022-06-03 14:11:42.045146015 UTC              4127.7
# 5   2022-06-03 14:12:54.849271387 UTC              4127.3
# 6   2022-06-03 14:21:35.300407560 UTC              4127.7
# 7   2022-06-03 17:04:07.858066552 UTC             12639.1
# 8   2022-06-03 18:29:59.209613837 UTC              4123.3
# 0   2022-06-01 07:07:26.568277335 UTC             14461.4
# 1   2022-06-01 07:09:33.715113839 UTC             14461.4
# 2   2022-06-01 07:15:04.294151673 UTC             14461.4
# 3   2022-06-01 07:17:23.138732901 UTC             14461.4
# 4   2022-06-01 07:20:53.361789086 UTC             14461.4
# 5   2022-06-01 07:23:54.347989952 UTC             14460.0
# 6   2022-06-01 07:25:48.277022078 UTC             14460.0
# 7   2022-06-01 07:29:05.681830894 UTC             14461.4
# 8   2022-06-01 07:32:00.555507478 UTC             14460.0
# 9   2022-06-01 07:41:13.529601682 UTC             14461.4
# 10  2022-06-01 12:27:08.266171628 UTC             14460.0
